# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "../Data/raw_ai_student_impact_dataset (1).csv"
)

df.head()

# %%
df.info()

df.isnull().sum()

df.duplicated().sum()

# %% [markdown]
# 50k rows 16 Columns
# 0 empty values
# 0 duplicated

# %%
for col in ["Major_Category", "Year_of_Study", "Primary_Use_Case", "Burnout_Risk_Level"]:
    print("\n", col)
    print(df[col].value_counts())

# %%
df["gpa_change"] = (
    df["Post_Semester_GPA"]
    - df["Pre_Semester_GPA"]
)

df.head()

# %%
df.groupby(
    "Paid_Subscription"
)["gpa_change"].mean()
# Out:
# Paid_Subscription
# False    0.200429
# True     0.206971
# Name: gpa_change, dtype: float64

# %%
df.to_csv(
    "../Data/cleaned_ai_student.csv",
    index=False
)
